# %% [markdown]
# # Machine Translation Automatic Metrics
#
# - BLEU
# - chrF
# - COMET
#
# First we will install the required libraries.

# %%
# install the metrics
# we only have to do it once per session
# install BLEU and chrF
# !pip install sacrebleu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#install COMET
# !pip install unbabel-comet==1.1.2 --use-feature=2020-resolver
# Out:
# WARNING: --use-feature=2020-resolver no longer has any effect, since it is now the default dependency resolver in pip. This will become an error in pip 21.0.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 64 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 585 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 47.1 MB/s
# ...
#      |████████████████████████████████| 9.5 MB 44.0 MB/s
# ...
#      |████████████████████████████████| 4.9 MB 41.4 MB/s
# ...
#      |████████████████████████████████| 116 kB 59.7 MB/s
# ...
#      |████████████████████████████████| 409 kB 64.4 MB/s
# ...
#      |████████████████████████████████| 101 kB 13.1 MB/s
# ...
#      |████████████████████████████████| 120 kB 61.5 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 56.0 MB/s
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
# ...

# %% [markdown]
# ## Upload Text Files
#
# We need to upload the text files with the Source, Reference translation, and MT systems (engines) output.

# %%
#upload source file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4f929274-aa22-407c-a13b-fe7cf14a45fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f929274-aa22-407c-a13b-fe7cf14a45fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#upload system 1 output 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9236680c-ac14-4bd8-8b53-34d462813e25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9236680c-ac14-4bd8-8b53-34d462813e25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#upload system 2 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a9bd156-1bc4-4706-a728-48ff8e62113d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a9bd156-1bc4-4706-a728-48ff8e62113d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#upload reference
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-861d01d8-a8b6-4fb1-b3d1-45259b46ba74" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-861d01d8-a8b6-4fb1-b3d1-45259b46ba74">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Compute BLEU and chrF Scores

# %%
#compute BLEU and chrF reference with system 1
# !sacrebleu en-ro.abstracts.ro -l en-ro -i en-ro.test.mbart.sys.hyp -m bleu chrf
# Out:
# [
# {
#  "name": "BLEU",
#  "score": 22.0,
#  "signature": "nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.2.1",
#  "verbose_score": "50.9/27.0/16.4/10.3 (BP = 1.000 ratio = 1.018 hyp_len = 8407 ref_len = 8255)",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.2.1"
# },
# {
#  "name": "chrF2",
#  "score": 51.5,
#  "signature": "nrefs:1|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.2.1",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "yes",
#  "nc": "6",
#  "nw": "0",
#  "space": "no",
#  "version": "2.2.1"
# }
# ]

# %%
#compute BLEU and chrF reference with system 2
# !sacrebleu en-ro.abstracts.ro -i en-ro.test.mbartft.emea.sys.hyp -m bleu chrf
# Out:
# [
# {
#  "name": "BLEU",
#  "score": 25.8,
#  "signature": "nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.2.1",
#  "verbose_score": "54.5/30.9/20.0/13.2 (BP = 1.000 ratio = 1.001 hyp_len = 8267 ref_len = 8255)",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.2.1"
# },
# {
#  "name": "chrF2",
#  "score": 54.9,
#  "signature": "nrefs:1|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.2.1",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "yes",
#  "nc": "6",
#  "nw": "0",
#  "space": "no",
#  "version": "2.2.1"
# }
# ]

# %% [markdown]
# # Compute COMET Scores

# %%
# compute COMET  system 1
#comet downloads a language model once per session
# !comet-score -s en-ro.abstracts.en -t en-ro.test.mbart.sys.hyp -r en-ro.abstracts.ro
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]
# Global seed set to 12
# wmt20-comet-da.tar.gz: 1.79GB [00:44, 40.0MB/s]
# Downloading: 100% 5.07M/5.07M [00:00<00:00, 27.6MB/s]
# Downloading: 100% 616/616 [00:00<00:00, 549kB/s]
# Downloading: 100% 2.24G/2.24G [00:47<00:00, 47.2MB/s]
# Some weights of the model checkpoint at xlm-roberta-large were not used when initializing XLMRobertaModel: ['lm_head.layer_norm.weight', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# ...

# %%
# !comet-score -s en-ro.abstracts.en -t en-ro.test.mbartft.emea.sys.hyp -r en-ro.abstracts.ro
# Out:
# Global seed set to 12
# Some weights of the model checkpoint at xlm-roberta-large were not used when initializing XLMRobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing XLMRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...

# %% [markdown]
# # Significance Test for BLEU

# %%
# !sacrebleu en-ro.abstracts.ro -l en-ro -i en-ro.test.mbart.sys.hyp en-ro.test.mbartft.emea.sys.hyp  -m bleu --paired-bs
# Out:
# sacreBLEU: Found 2 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: en-ro.test.mbart.sys.hyp'
# sacreBLEU: Computing BLEU for 'en-ro.test.mbartft.emea.sys.hyp' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# ╒════════════════════════════════════╤═════════════════════╕
# │                             System │  BLEU (μ ± 95% CI)  │
# ╞════════════════════════════════════╪═════════════════════╡
# │ Baseline: en-ro.test.mbart.sys.hyp │  22.0 (22.0 ± 2.0)  │
# ├────────────────────────────────────┼─────────────────────┤
# │    en-ro.test.mbartft.emea.sys.hyp │  25.8 (25.7 ± 2.1)  │
# │                                    │    (p = 0.0010)*    │
# ╘════════════════════════════════════╧═════════════════════╛
#
# ------------------------------------------------------------
# Paired bootstrap resampling test with 1000 resampling trials
# ------------------------------------------------------------
# ...
